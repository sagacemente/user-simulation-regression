# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import os
import torch

# %%
def create_balanced_grids(df_res, num_grid,balance:list = ['topic', 'fake']):
  '''Create grids balanced by topic and fake/true
  Input: num_girds, pd.DataFrame with in each row an image. Each column is a feature. Mandatory columns are topic and the labelcolumn
  Output: return a dictionary where each key is the index of the grid and the value is a list with the name of the images '''
  
  dict_grid = dict()
  df_copy = df_res.copy()
  groups = df_copy.groupby(balance)
  classes={}
  classes_count={}
  #crea per ogni gruppo le classi in base a cred e manip per potere usare tutte quelle meno frequenti
  for group in groups: 
    #temp=group[1].groupby(['cred','manip'])
    temp=group[1].groupby(['authenticity'])
    classes[group[0]]={}
    classes_count[group[0]]={}
    for dclass in temp:
      #classes[group[0]][dclass[0]]=[(dclass[1]["folder"][i]+os.path.sep +i) for i in dclass[1].index.tolist()]      
      classes[group[0]][dclass[0]]=[(dclass[1]['path_drive_not_annotated'][i]+os.path.sep +i) for i in dclass[1].index.tolist()]
      classes_count[group[0]][dclass[0]]=[0,len(classes[group[0]][dclass[0]])]
      
  
  listofimages=[]
  for grid in range(num_grid):
    # print("grid:",grid)  
    dict_grid[grid] = []
    for group in groups:
      min_el=1000
      min_classes=[]
      for dclass_k, dclass_v in classes[group[0]].items():
        # print(group[0],'len',len(dclass[1]))
        lendclass=classes_count[group[0]][dclass_k][0]
        if lendclass<min_el and lendclass < classes_count[group[0]][dclass_k][1]:
          #print("lendclass",lendclass,"classes_count",classes_count[group[0]][dclass_k][1])
          min_el=lendclass
          min_classes=[dclass_k]
          classes_counts=classes_count[group[0]][dclass_k][1]
        elif lendclass==min_el and lendclass < classes_count[group[0]][dclass_k][1]:
          min_classes.append(dclass_k)
      sel_class_k= random.choice(min_classes)
      sel_class_v=classes[group[0]][sel_class_k]
      # print("sellendclass",classes_count[group[0]][sel_class_k][0],"sel_classes_count",classes_count[group[0]][sel_class_k][1])    
      # print("selected class pre",sel_class_v)
      topic_sample =random.choice(sel_class_v)
      # print("topic_sample",topic_sample)
      # print(group[0],"sel class pre",sel_class_k,len(sel_class_v))
      sel_class_v.remove(topic_sample)
      #print(group[0],"sel class post",sel_class_k,len(sel_class_v))
      classes_count[group[0]][sel_class_k][0]+=1
      dict_grid[grid].append(topic_sample)
      listofimages.append(topic_sample)
    #print("grid",dict_grid[grid])
    random.shuffle(dict_grid[grid])
    #print("grid",dict_grid[grid])

  #assert (len(list(pd.DataFrame.from_dict(dict_grid).values.reshape(-1)))  == len(set(list(pd.DataFrame.from_dict(dict_grid).values.reshape(-1))))), 'Huston Problem'
  # print( len(listofimages))
  # print(listofimages)
  # print( len(set(listofimages)))
  # print(set(listofimages))
  # print("duplicates", [k for k,v in Counter(listofimages).items() if v>1])
  assert(len(listofimages)==len(set(listofimages)))
  random.shuffle(dict_grid)
  return dict_grid

# %%
path_fra = '/content/drive/MyDrive/Qualtrics_Annotator/DEF_images_data.xlsx'
df = pd.read_excel(path_fra, index_col=0)
df.head(4)
# Out:
#                              topic t_f authenticity  \
# space_rover_sistem_TRUE.jpg  space   T            T
# nasa_fake_mars_rover.jpg     space   F            T
# true_hubble_space_nasa.jpg   space   T            T
# ppDaE4bmoY98e2J7LezDvK.jpg   space   T            T
#
#                                                                            url  \
# space_rover_sistem_TRUE.jpg  https://www.jpl.nasa.gov/news/twin-of-nasas-pe...
# nasa_fake_mars_rover.jpg     https://edition.cnn.com/2016/07/15/health/mars...
# true_hubble_space_nasa.jpg   https://web.astropiombino.org/web/wp-content/u...
# ppDaE4bmoY98e2J7LezDvK.jpg   https://www.nbcnews.com/mach/science/here-s-wh...
#
#                              virality  \
# space_rover_sistem_TRUE.jpg  4.027092
# nasa_fake_mars_rover.jpg     3.040368
# true_hubble_space_nasa.jpg   1.949575
# ppDaE4bmoY98e2J7LezDvK.jpg   2.927303
#
#                                                                      interpret  \
# space_rover_sistem_TRUE.jpg  Updated with new features, including additiona...
# nasa_fake_mars_rover.jpg     NASA’s Mars 2020 rover will explore the Red Pl...
# true_hubble_space_nasa.jpg                        Hubble Looks at Helix Nebula
# ppDaE4bmoY98e2J7LezDvK.jpg   Elon Musk posted this "last pic" of the red Te...
#
#                                                          NOT_ann_qualtrics_url  \
# space_rover_sistem_TRUE.jpg  <img src="https://qfreeaccountssjc1.az1.qualtr...
# nasa_fake_mars_rover.jpg     <img src="https://qfreeaccountssjc1.az1.qualtr...
# true_hubble_space_nasa.jpg   <img src="https://qfreeaccountssjc1.az1.qualtr...
# ppDaE4bmoY98e2J7LezDvK.jpg   <img src="https://qfreeaccountssjc1.az1.qualtr...
#
#                                                       path_drive_not_annotated  \
# space_rover_sistem_TRUE.jpg  /content/drive/MyDrive/Resized_images/space/sp...
# nasa_fake_mars_rover.jpg     /content/drive/MyDrive/Resized_images/space/na...
# true_hubble_space_nasa.jpg   /content/drive/MyDrive/Resized_images/space/tr...
# ppDaE4bmoY98e2J7LezDvK.jpg   /content/drive/MyDrive/Resized_images/space/pp...
#
#                             id_qualtrics_not_annotated_img  \
# space_rover_sistem_TRUE.jpg             IM_9B6a36NQaVHeL78
# nasa_fake_mars_rover.jpg                IM_eMcmqjB7SmJAPhY
# true_hubble_space_nasa.jpg              IM_3UBq6B8oHKLJ6Ps
# ppDaE4bmoY98e2J7LezDvK.jpg              IM_37YqrzryHAoBBRk
#
#                                                   annotated_name  \
# space_rover_sistem_TRUE.jpg  annoted_space_rover_sistem_TRUE.jpg
# nasa_fake_mars_rover.jpg        annoted_nasa_fake_mars_rover.jpg
# true_hubble_space_nasa.jpg    annoted_true_hubble_space_nasa.jpg
# ppDaE4bmoY98e2J7LezDvK.jpg    annoted_ppDaE4bmoY98e2J7LezDvK.jpg
#
#                             annotated_qualtrics_name    start_id  \
# space_rover_sistem_TRUE.jpg       IM_3qLneJI5SNDf6tM  <img src="
# nasa_fake_mars_rover.jpg          IM_06wFfIRn2n8NJXg  <img src="
# true_hubble_space_nasa.jpg        IM_d0Ymfvu1zYnRvWm  <img src="
# ppDaE4bmoY98e2J7LezDvK.jpg        IM_3fRwOrmvC1on2D4  <img src="
#
#                                                                      middle_id  \
# space_rover_sistem_TRUE.jpg  https://qfreeaccountssjc1.az1.qualtrics.com/Co...
# nasa_fake_mars_rover.jpg     https://qfreeaccountssjc1.az1.qualtrics.com/Co...
# true_hubble_space_nasa.jpg   https://qfreeaccountssjc1.az1.qualtrics.com/Co...
# ppDaE4bmoY98e2J7LezDvK.jpg   https://qfreeaccountssjc1.az1.qualtrics.com/Co...
#
#                             end_id  \
# space_rover_sistem_TRUE.jpg    "/>
# nasa_fake_mars_rover.jpg       "/>
# true_hubble_space_nasa.jpg     "/>
# ppDaE4bmoY98e2J7LezDvK.jpg     "/>
#
#                                                      annotated_qualttrics link  \
# space_rover_sistem_TRUE.jpg  <img src="https://qfreeaccountssjc1.az1.qualtr...
# nasa_fake_mars_rover.jpg     <img src="https://qfreeaccountssjc1.az1.qualtr...
# true_hubble_space_nasa.jpg   <img src="https://qfreeaccountssjc1.az1.qualtr...
# ppDaE4bmoY98e2J7LezDvK.jpg   <img src="https://qfreeaccountssjc1.az1.qualtr...
#
#                                                                       ita_trad  \
# space_rover_sistem_TRUE.jpg  Aggiornato con nuove funzionalità, tra cui sof...
# nasa_fake_mars_rover.jpg     Il rover Mars 2020 della NASA esplorerà il Pia...
# true_hubble_space_nasa.jpg               Hubble osserva la nebulosa dell'elica
# ppDaE4bmoY98e2J7LezDvK.jpg   Elon Musk ha pubblicato questa "ultima foto" d...
#
#                                       EST
# space_rover_sistem_TRUE.jpg     INTERPRET
# nasa_fake_mars_rover.jpg        INTERPRET
# true_hubble_space_nasa.jpg   NO_INTERPRET
# ppDaE4bmoY98e2J7LezDvK.jpg      INTERPRET

# %%
df.groupby(['topic',	't_f']).size()
# Out:
# topic            t_f
# commons          F      66
#                  T      58
# naturaldisaster  F      44
#                  T      74
# politics         F      47
#                  T      91
# space            F      49
#                  T      55
# dtype: int64

# %%
grids = create_balanced_grids(df, num_grid=35,balance=['topic', 't_f'])

# %%
grids
# Out:
# {0: ['/content/drive/MyDrive/strange_picturesstrange21.PNG/strange21.PNG',
#   '/content/drive/MyDrive/Resized_images/naturaldisaster/image.jpg/image.jpg',
#   '/content/drive/MyDrive/Resized_images/commons/bench.jpg/bench.jpg',
#   '/content/drive/MyDrive/Resized_images/space/space-weed.jpg/space-weed.jpg',
#   '/content/drive/MyDrive/Resized_images/politics/5f77363f220000ca2082beb9.jpeg/5f77363f220000ca2082beb9.jpeg',
#   '/content/drive/MyDrive/Resized_images/naturaldisaster/unnatoureiffelmed.jpg/unnatoureiffelmed.jpg',
#   '/content/drive/MyDrive/Resized_images/politics/baby-trump2.jpg/baby-trump2.jpg',
#   '/content/drive/MyDrive/Resized_images/space/1-wise-all-sky-image-16.jpg/1-wise-all-sky-image-16.jpg'],
#  1: ['/content/drive/MyDrive/Resized_images/naturaldisaster/GR-VFX-010.jpg/GR-VFX-010.jpg',
#   '/content/drive/MyDrive/Resized_images/politics/120418292_334300827831704_4979709850671689467_n.jpg/120418292_334300827831704_4979709850671689467_n.jpg',
#   '/content/drive/MyDrive/Resized_images/naturaldisaster/6FLOODS1-superJumbo.jpg/6FLOODS1-superJumbo.jpg',
#   '/content/drive/MyDrive/Resized_images/space/ezgif-frame-042.jpg/ezgif-frame-042.jpg',
#   '/content/drive/MyDrive/Resized_images/politics/ar43BY5_460s.jpg/ar43BY5_460s.jpg',
#   '/content/drive/MyDrive/strange_picturesstr
jpg',
#   '/content/drive/MyDrive/Resized_images/politics/ap_clinton_lb_150319_16x9_992.jpg/ap_clinton_lb_150319_16x9_992.jpg',
#   '/content/drive/MyDrive/Resized_images/politics/baby-trump1.jpg/baby-trump1.jpg',
#   '/content/drive/MyDrive/strange_picturesstrange11.PNG/strange11.PNG',
#   '/content/drive/MyDrive/Resized_images/naturaldisaster/tsunami faro.PNG/tsunami faro.PNG',
#   '/content/drive/MyDrive/Resized_images/commons/rice.jpg/rice.jpg'],
#  32: ['/content/drive/MyDrive/Resized_images/space/moonnasalastphoto.PNG/moonnasalastphoto.PNG',
#   '/content/drive/MyDrive/Resized_images/naturaldisaster/citiy sub.PNG/citiy sub.PNG',
#   '/content/drive/MyDrive/Resized_images/naturaldisaster/5c54843d56ed8.image.jpg/5c54843d56ed8.image.jpg',
#   '/content/drive/MyDrive/Resized_images/politics/eKcPbZFxqrO5eo_ACCuIm6KQ-M0gprJGKcriVLwL1po.jpg/eKcPbZFxqrO5eo_ACCuIm6KQ-M0gprJGKcriVLwL1po.jpg',
#   '/content/drive/MyDrive/Resized_images/politics/bidn fake2.jpg/bidn fake2.jpg',
#   '/content/drive/MyDrive/Resized_images/commons/https___blogs-images.forbes.com_fernandoalfonso_files_2019_01_trump-wall1-1200x1111.jpg/https___blogs-images.forbes.com_fernandoalfonso_files_2019_01_trump-wall1-1200x1111.jpg',
#   '/content/drive/MyDrive/Resized_images/commons/dalek.jpg/dalek.jpg',
#   '/content/drive/MyDrive/Resized_images/space/gravity-movie-7.jpg/gravity-movie-7.jpg'],
#  33: ['/content/drive/MyDrive/Resized_images/commons/fishes.jpg/fishes.jpg',
#   '/content/drive/MyDrive/Resized_images/naturaldisaster/2CLQ_20150710-042045_Canon-EOS-6D__MG_9123_tapiro.jpg/2CLQ_20150710-042045_Canon-EOS-6D__MG_9123_tapiro.jpg',
#   '/content/drive/MyDrive/Resized_images/space/MjVVmKaKu53xwCNRw48jX7.jpg/MjVVmKaKu53xwCNRw48jX7.jpg',
#   '/content/drive/MyDrive/Resized_images/politics/imagestrump.jpg/imagestrump.jpg',
#   '/content/drive/MyDrive/Resized_images/space/180312-nasa-hammer-asteroids-feature.jpg/180312-nasa-hammer-asteroids-feature.jpg',
#   '/content/drive/MyDrive/Resized_images/naturaldisaster/A6ZJCLdCcAAG_JL.jpg/A6ZJCLdCcAAG_JL.jpg',
#   '/content/drive/MyDrive/Resized_images/commons/barbie_box_front.jpg/barbie_box_front.jpg',
#   '/content/drive/MyDrive/Resized_images/politics/merlin_186946455_351092eb-7793-45c5-b105-f197d9c57d32-mobileMasterAt3x.jpg/merlin_186946455_351092eb-7793-45c5-b105-f197d9c57d32-mobileMasterAt3x.jpg'],
#  34: ['/content/drive/MyDrive/Resized_images/commons/Et8OUVEXAAMrnmj.jpg/Et8OUVEXAAMrnmj.jpg',
#   '/content/drive/MyDrive/Resized_images/space/63kMPdgW6yAaL6XGCbMJQa.jpg/63kMPdgW6yAaL6XGCbMJQa.jpg',
#   '/content/drive/MyDrive/Resized_images/space/nasaposters6.jpeg/nasaposters6.jpeg',
#   '/content/drive/MyDrive/Resized_images/naturaldisaster/Fossil-Fuels-1.jpg/Fossil-Fuels-1.jpg',
#   '/content/drive/MyDrive/Resized_images/politics/DJYZZ5l-Copyeee.jpg/DJYZZ5l-Copyeee.jpg',
#   '/content/drive/MyDrive/Resized_images/commons/downloadavocado.jpg/downloadavocado.jpg',
#   '/content/drive/MyDrive/Resized_images/naturaldisaster/berlindestoryed2.jpg/berlindestoryed2.jpg',
#   '/content/drive/MyDrive/Resized_images/politics/download (18).jpg/download (18).jpg']}

# %%
torch.save(grids, 'grids_all_imgs.pt')
